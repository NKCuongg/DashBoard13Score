# %%
import pandas as pd
import firebase_admin
from firebase_admin import credentials, firestore

# %%
df = pd.read_csv('orginal_sales_data_edit.csv', encoding='utf-8', header=0,delimiter=',')

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
#
#   CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME
# 0             Kwai    Small         Yu Kwai
# 1             Paul    Small    Henriot Paul
# 2           Daniel   Medium  DaCunha Daniel
# 3            Julie   Medium     Young Julie
# 4            Julie   Medium     Brown Julie
#
# [5 rows x 28 columns]

# %%
cred = credentials.Certificate("./iuh-20007141-firebase-adminsdk-y1n0e-183adc1e34.json")
firebase_admin.initialize_app(cred)

# %%
dbFireStore = firestore.client()

# %%
for item in df.to_dict(orient='records'):
    doc_ref = dbFireStore.collection('tbl-20007141').document()
    doc_ref.set(item)

# %%
queryResults = list(dbFireStore.collection(u'tbl-20007141').limit(5).stream())
listQueryResult = list(map(lambda x: x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#   TERRITORY  ORDERLINENUMBER  SUBCATEGORY          CITY   STATUS  \
# 0      EMEA                8       Eraser        Bergen  Shipped
# 1      APAC               13        Table  North Sydney  Shipped
# 2       NaN                9  Smart watch     Tsawassen  Shipped
# 3     Japan                4         Lamp     Singapore  Shipped
# 4       NaN               16          Pen    San Rafael  Shipped
#
#                            ADDRESSLINE1 ADDRESSLINE2  YEAR_ID CONTACTLASTNAME  \
# 0           Drammen 121, PR 744 Sentrum          NaN     2003          Oeztan
# 1                     201 Miller Street     Level 15     2003          O'Hara
# 2                    23 Tsawassen Blvd.          NaN     2004         Lincoln
# 3  Bronz Sok., Bronz Apt. 3/6 Tesvikiye          NaN     2003       Natividad
# 4                       5677 Strong St.          NaN     2003          Nelson
#
#      COUNTRY  ...  ORDERNUMBER           PHONE  DEALSIZE  MONTH_ID  \
# 0     Norway  ...        10181   +47 2267 3215     Small        11
# 1  Australia  ...        10148    02 9936 8555     Small         9
# 2     Canada  ...        10235  (604) 555-4555     Small         4
# 3  Singapore  ...        10150    +65 221 7555     Small         9
# 4        USA  ...        10142      4155551450    Medium         8
#
#      PAYMENTFULLNAME STATE MSRP         CATEGORY  PRODUCTCODE POSTALCODE
# 0      Oeztan Veysel   NaN   37  Office Supplies     S24_2972     N 5804
# 1        O'Hara Anna   NSW  141        Furniture     S18_1129       2060
# 2  Lincoln Elizabeth    BC   80       Technology    S700_3167    T2F 8M4
# 3     Natividad Eric   NaN   64  Office Supplies     S32_3522      79903
# 4     Nelson Valarie    CA   62  Office Supplies     S32_3207      97562
#
# [5 rows x 28 columns]
